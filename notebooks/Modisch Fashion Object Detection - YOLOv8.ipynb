# %%
import os
import kaggle
import yaml
import pathlib
import random
import shutil
import torch
import sys
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np

#test pr
# Notebook can't use relative package imports; ensure src is on sys.path and import absolutely.
sys.path.append(str(pathlib.Path('..').resolve() / 'src'))
from modeling.common import switch_labels

if os.path.exists('yolov8n.pt'):
    os.remove('yolov8n.pt')
    print("Removed corrupted yolov8n.pt file. It will be redownloaded automatically.")

print('Data source import complete.')
# Out:
# Removed corrupted yolov8n.pt file. It will be redownloaded automatically.
# Data source import complete.

# %%
# Add this as a new cell after the imports cell

# !kaggle datasets download -d nguyngiabol/colorful-fashion-dataset-for-object-detection && unzip colorful-fashion-dataset-for-object-detection.zip -d ../dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nguyngiabol/colorful-fashion-dataset-for-object-detection
# License(s): unknown
# Downloading colorful-fashion-dataset-for-object-detection.zip to /Users/macm4/repositories/2Phase-Object-Detection/notebooks
# 100%|███████████████████████████████████████▊| 104M/104M [00:16<00:00, 6.20MB/s]
# 100%|████████████████████████████████████████| 104M/104M [00:16<00:00, 6.45MB/s]
# Archive:  colorful-fashion-dataset-for-object-detection.zip
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100034.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100073.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100088.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100221.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100232.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100247.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100254.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10031.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10032.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10042.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100599.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10071.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100824.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10084.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100922.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/100932.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101074.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10117.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101171.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101255.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101269.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101296.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101304.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10132.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101339.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101393.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101443.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101453.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101691.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101723.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10174.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101796.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101805.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/101957.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102134.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102162.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102182.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10225.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10226.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102284.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102358.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102400.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102478.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1025.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102541.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102551.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102554.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102581.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10280.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102817.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102867.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102919.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102944.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/102949.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103060.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103062.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103084.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10312.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103194.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103365.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103368.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103371.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103419.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103483.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103631.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103650.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10376.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103777.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103789.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103801.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103819.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103948.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103989.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/103992.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104001.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104019.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104101.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104108.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104163.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104183.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104193.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104194.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104221.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104259.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104312.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104456.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104485.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104499.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104521.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104565.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104572.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104589.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10466.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104727.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104754.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10477.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104786.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104795.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104798.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104835.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104881.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104921.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/104962.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105021.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105059.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105091.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105172.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105231.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105274.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105307.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105422.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105423.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105432.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105494.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105559.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10556.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105606.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105645.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105653.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105683.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105705.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105720.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105845.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105848.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105861.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105946.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105948.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/105954.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106049.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106101.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106106.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106141.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106182.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106225.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106309.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106320.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106322.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106349.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106357.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106419.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10643.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106501.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106661.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106671.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106672.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106706.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106825.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106830.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/106831.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107046.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107061.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107069.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10708.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107115.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107120.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107164.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1074.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107473.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107560.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107606.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107616.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107702.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/107996.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108004.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108037.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108105.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108117.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108127.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108128.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108154.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108234.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108331.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108366.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108416.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108469.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108482.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108549.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108640.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108643.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108690.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108721.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108752.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108854.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10888.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/108982.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109035.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109282.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109423.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109437.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109454.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10947.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109496.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109553.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/10971.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109746.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109763.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109781.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/109813.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110028.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110094.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11010.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110166.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110171.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110249.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110393.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110461.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110606.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110686.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110739.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110810.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110861.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/110899.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111018.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111086.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111139.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111365.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111444.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111451.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11153.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111723.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111805.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/111964.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112148.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112150.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112233.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112317.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112412.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112448.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11260.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112639.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112680.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/112779.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113018.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113077.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113128.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113257.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113294.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11338.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113416.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113476.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11355.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11382.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113906.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113922.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/113932.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11394.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114150.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114166.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114201.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114277.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114286.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114288.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114635.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1147.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11479.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114792.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114873.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114880.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114884.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114887.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/114951.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/115148.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/115471.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/115477.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/115659.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/115988.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116147.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116300.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116453.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116495.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11653.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116718.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11674.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116880.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/116947.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11702.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11709.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117111.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117140.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11717.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117304.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117336.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117375.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117578.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117658.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117662.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117697.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117704.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/117804.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118315.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118418.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118509.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118534.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118547.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11857.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118582.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118662.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118698.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118758.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118766.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118804.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11881.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118849.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/118853.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119006.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119093.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119126.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119177.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11918.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119314.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119534.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119544.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/11960.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119650.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/119835.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1200.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120212.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120376.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120590.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120646.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120690.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120762.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120789.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/120874.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121018.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121133.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121162.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121260.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121266.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121268.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121328.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121359.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121410.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121414.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121499.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121569.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12170.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12175.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121834.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/121999.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122173.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122270.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122331.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12260.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122668.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122697.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/122869.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123028.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12315.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123189.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1232.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12325.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123353.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12343.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123629.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123769.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123850.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123917.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/123954.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124085.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124149.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124184.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124226.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124296.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124429.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12456.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124571.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124577.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12459.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124629.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124731.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/124775.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12484.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12486.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/125095.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/125257.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12553.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12561.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/125748.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12586.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/125865.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12598.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/125998.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12626.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/126287.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/126329.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/126448.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/126558.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/126735.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127072.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127254.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127410.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127469.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127537.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127567.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127597.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127704.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/127852.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12808.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128119.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12825.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128323.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128338.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128343.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128373.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12844.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1285.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128537.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128759.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128767.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12877.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128940.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/128943.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12900.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129061.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/12910.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129248.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129374.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129430.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129445.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129552.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129651.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129671.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129765.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129913.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129945.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/129960.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130027.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130298.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130306.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130321.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130366.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130408.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130475.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130551.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130638.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130669.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130801.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/130918.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131025.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131115.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131179.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131409.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131422.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131443.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131495.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1315.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131545.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131710.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131845.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131895.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13194.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131948.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/131985.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132315.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13233.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132393.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132530.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132600.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132743.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132857.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132974.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/132978.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133008.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13302.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133265.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133345.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133533.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133549.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133722.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133734.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13386.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133871.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/133950.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134101.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134164.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134382.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13441.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134423.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134447.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134493.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134526.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/134588.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13469.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135195.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13525.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13527.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135478.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135674.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135684.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13579.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135831.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/135835.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/136011.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/136027.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/1361.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/13632.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/136335.xml
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/Annotations/136338.xml
# ...
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88068.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88124.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88148.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88210.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88380.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88450.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/8853.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88531.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88544.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88576.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88617.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88622.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88633.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88640.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88648.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88673.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88919.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/88989.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89009.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/8911.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89135.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89286.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89413.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89417.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89435.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89446.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89468.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89538.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89667.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89721.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89736.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89781.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89888.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/89939.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9001.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90046.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90104.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9015.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90173.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90467.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90583.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90599.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90653.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90664.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9068.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9069.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90713.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9083.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90834.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90852.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90855.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9093.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/90950.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9096.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91120.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9123.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91254.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91366.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91368.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9150.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91692.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91736.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91744.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/91857.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9192.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92070.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92215.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92267.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9231.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92467.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92616.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92632.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92656.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9267.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92878.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92890.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92930.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/92963.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9313.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93387.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93411.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93586.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93834.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93855.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93884.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93972.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/93994.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94181.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/942.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94218.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94359.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9441.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94452.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94547.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94570.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94673.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9473.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94801.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/949.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/94987.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95019.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95122.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95222.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9527.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95372.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/954.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95583.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95636.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/95703.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9579.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96004.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96042.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96109.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96275.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96310.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96397.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96428.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96551.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96706.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96743.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/96788.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97001.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97020.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97150.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97222.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97223.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97339.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97343.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97381.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97422.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9753.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97591.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97685.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9779.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9785.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/97943.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98034.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98051.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98155.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98175.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98302.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98335.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98409.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98532.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98712.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98768.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98965.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/98986.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99019.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99040.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99061.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99066.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99108.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99188.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/9920.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99278.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99316.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/994.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99503.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99557.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99561.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99599.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99600.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99607.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99611.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99618.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99672.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99864.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99947.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99952.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages/99960.jpg
#   inflating: ../dataset/colorful_fashion_dataset_for_object_detection/labels.txt

# %% [markdown]
# # YOLOv8
# YOLOv8 is the newest state-of-the-art YOLO model that can be used for object detection, image classification, and instance segmentation tasks.<br>
# YOLOv8 includes numerous architectural and developer experience changes and improvements over YOLOv5.<br>
#
# ## Why Should I Use YOLOv8?
# * YOLOv8 has a high rate of accuracy measured by COCO and Roboflow 100.
# * YOLOv8 comes with a lot of developer-convenience features, from an easy-to-use CLI to a well-structured Python package.

# %%
# Paths (match your notebook variables)
output_path = '../dataset'
dataset_root = os.path.join(output_path, 'colorful_fashion_dataset_for_object_detection')
jpeg_dir = os.path.join(dataset_root, 'JPEGImages')
images_alias = os.path.join(dataset_root, 'images')  # YOLO-friendly
labels_dir = os.path.join(dataset_root, 'labels')    # where your phase labels are moved before training
original_annotations_path = os.path.join(dataset_root, 'Annotations_txt')

# 1) Make 'images' alias -> JPEGImages
if not os.path.exists(images_alias):
    try:
        os.symlink(os.path.relpath(jpeg_dir, dataset_root), images_alias)
        print(f"✅ Symlink created: {images_alias} -> {jpeg_dir}")
    except Exception as e:
        # Fallback: duplicate folder name (uses extra space)
        if not os.path.exists(images_alias):
            shutil.copytree(jpeg_dir, images_alias)
            print(f"✅ Copied images to: {images_alias}")
# Out:
# ✅ Symlink created: ../dataset/colorful_fashion_dataset_for_object_detection/images -> ../dataset/colorful_fashion_dataset_for_object_detection/JPEGImages

# %%
# 2) Move phase labels to 'labels' directory
def move_dir_overwrite(src, dst):
    if not os.path.exists(src):
        print(f"Skip move: missing {src}")
        return
    if os.path.exists(dst):
        # avoid rmtree if they are the same inode
        try:
            if os.path.samefile(src, dst):
                return
        except FileNotFoundError:
            pass
        shutil.rmtree(dst)
    shutil.move(src, dst)

# %%
# 2) Regenerate train/val lists that point to the 'images' alias
def resolve_image_path(img_name, images_dir):
    img_name = img_name.strip()
    if not img_name:
        return None
    exts = ('.jpg', '.jpeg', '.png', '.JPG', '.PNG')
    cands = [img_name] if os.path.splitext(img_name)[1] else [img_name + ext for ext in exts]
    for c in cands:
        p = os.path.join(images_dir, c)
        if os.path.exists(p):
            return os.path.abspath(p)
    base = os.path.splitext(img_name)[0]
    for f in os.listdir(images_dir):
        if os.path.splitext(f)[0] == base:
            return os.path.abspath(os.path.join(images_dir, f))
    return None

def make_list_from_imagesets(images_dir, list_relpath, out_txt):
    list_path = os.path.join(dataset_root, list_relpath)
    lines = []
    if os.path.exists(list_path):
        with open(list_path, 'r') as f:
            for l in f:
                p = resolve_image_path(l, images_dir)
                if p:
                    lines.append(p)
    else:
        print(f"⚠️ Missing: {list_path}")
    with open(out_txt, 'w') as f:
        f.write("\n".join(lines))
    print(f"✅ Wrote {out_txt} with {len(lines)} entries")

train_list_txt = os.path.abspath(os.path.join(dataset_root, 'train_full.txt'))
val_list_txt   = os.path.abspath(os.path.join(dataset_root, 'val_full.txt'))

make_list_from_imagesets(images_alias, 'ImageSets/Main/trainval.txt', train_list_txt)
make_list_from_imagesets(images_alias, 'ImageSets/Main/test.txt',     val_list_txt)

# 3) Rewrite YAMLs to reference these lists
def write_phase_yaml(path_root, train_txt, val_txt, names, out_fname):
    cfg = {
        'path': os.path.abspath(path_root),
        'train': os.path.abspath(train_txt),
        'val': os.path.abspath(val_txt),
        'names': {i: n for i, n in enumerate(names)},
    }
    with open(out_fname, 'w') as f:
        yaml.dump(cfg, f, sort_keys=False)
    print(f"✅ Wrote {out_fname}")

phase1_names = ['TOP','BOTTOM','SHOES']
phase2_names = ['jacket','shirt','pants','shorts','skirt','dress','shoe', 'slipper']

write_phase_yaml(dataset_root, train_list_txt, val_list_txt, phase1_names, 'phase1-data.yaml')
write_phase_yaml(dataset_root, train_list_txt, val_list_txt, phase2_names, 'phase2-data.yaml')

# 4) Clear stale caches so YOLO reindexes with labels
for cache_name in ('JPEGImages.cache', 'images.cache'):
    cp = os.path.join(dataset_root, cache_name)
    if os.path.exists(cp):
        os.remove(cp)
        print(f"🗑️ Removed cache: {cp}")

print("Done. Now ensure labels_dir points to the correct phase before training.")
# Out:
# ✅ Wrote /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/train_full.txt with 2145 entries
# ✅ Wrote /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/val_full.txt with 537 entries
# ✅ Wrote phase1-data.yaml
# ✅ Wrote phase2-data.yaml
# Done. Now ensure labels_dir points to the correct phase before training.

# %%
# Original classes from the downloaded dataset's labels.txt
original_classes = {
    0: 'sunglass', 1: 'hat', 2: 'jacket', 3: 'shirt', 4: 'pants',
    5: 'shorts', 6: 'skirt', 7: 'dress', 8: 'bag', 9: 'shoe',
    10: 'slipper'
}

# PHASE 1: New coarse classes (TOP, BOTTOM, SHOES)
phase1_classes = {'TOP': 0, 'BOTTOM': 1, 'SHOES': 2}
# This maps the ORIGINAL class ID to the NEW Phase 1 class ID
phase1_map = {
    0: None,  # sunglass
    1: None,  # hat
    2: 0,     # jacket -> TOP
    3: 0,     # shirt  -> TOP
    4: 1,     # pants  -> BOTTOM
    5: 1,     # shorts -> BOTTOM
    6: 1,     # skirt  -> BOTTOM
    7: 0,     # dress  -> TOP
    8: None,  # bag
    9: 2,
    10: 2,     # shoe   -> SHOES
}

# PHASE 2: Your new fine-grained classes (without sunglass, bag, hat)
phase2_classes = {
    'jacket': 0, 'shirt': 1, 'pants': 2, 'shorts': 3,
    'skirt': 4, 'dress': 5, 'shoe': 6, 'slipper': 7
}
# This maps the ORIGINAL class ID to the NEW Phase 2 class ID
phase2_map = {
    0: None,  # sunglass
    1: None,  # hat
    2: 0,     # jacket
    3: 1,     # shirt
    4: 2,     # pants
    5: 3,     # shorts
    6: 4,     # skirt
    7: 5,     # dress
    8: None,  # bag
    9: 6,     # shoe
    10: 7    # slipper
}

# %%
labels_phase1_dir = os.path.join(dataset_root, 'labels_phase1')
labels_phase2_dir = os.path.join(dataset_root, 'labels_phase2')

# %%
# --- 3. Create the new label directories ---
# Clear any old directories first and create clean ones
if os.path.exists(labels_phase1_dir): shutil.rmtree(labels_phase1_dir)
os.makedirs(labels_phase1_dir)

if os.path.exists(labels_phase2_dir): shutil.rmtree(labels_phase2_dir)
os.makedirs(labels_phase2_dir)

# %%
# --- 4. Process each original label file ---
processed_files = 0
for filename in os.listdir(original_annotations_path):
    if not filename.endswith('.txt'):
        continue

    new_phase1_lines = []
    new_phase2_lines = []

    with open(os.path.join(original_annotations_path, filename), 'r') as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue

            try:
                original_class_id = int(parts[0])
            except ValueError:
                continue

            box_coords = ' '.join(parts[1:])

            # --- Process for Phase 1 ---
            if original_class_id in phase1_map:
                new_class_id = phase1_map[original_class_id]
                if new_class_id is not None:
                    new_phase1_lines.append(f"{new_class_id} {box_coords}")

            # --- Process for Phase 2 ---
            if original_class_id in phase2_map:
                new_class_id = phase2_map[original_class_id]
                if new_class_id is not None:
                    new_phase2_lines.append(f"{new_class_id} {box_coords}")

    # Write the new, filtered label files for each phase (create empty file if nothing)
    with open(os.path.join(labels_phase1_dir, filename), 'w') as f:
        if new_phase1_lines:
            f.write('\n'.join(new_phase1_lines))

    with open(os.path.join(labels_phase2_dir, filename), 'w') as f:
        if new_phase2_lines:
            f.write('\n'.join(new_phase2_lines))

    processed_files += 1

print(f"✅ Automatically processed {processed_files} files.")
print(f"-> Phase 1 labels are ready in: '{labels_phase1_dir}'")
print(f"-> Phase 2 labels are ready in: '{labels_phase2_dir}'")
# ...existing code...
# Out:
# ✅ Automatically processed 2683 files.
# -> Phase 1 labels are ready in: '../dataset/colorful_fashion_dataset_for_object_detection/labels_phase1'
# -> Phase 2 labels are ready in: '../dataset/colorful_fashion_dataset_for_object_detection/labels_phase2'

# %%
# 1) Device detection (CUDA preferred, then MPS on Apple silicon, else CPU)
device = 'cuda' if torch.cuda.is_available() else ('mps' if getattr(torch.backends, 'mps', None) and torch.backends.mps.is_available() else 'cpu')
print("Using device:", device)

# 2) Quick label-coverage check (counts non-empty label files for train/val lists)
def check_label_coverage(list_txt, labels_dir):
    imgs = []
    with open(list_txt, 'r') as f:
        imgs = [l.strip() for l in f if l.strip()]
    non_empty = 0
    missing = 0
    for p in imgs:
        base = os.path.splitext(os.path.basename(p))[0]
        lf = os.path.join(labels_dir, base + '.txt')
        if not os.path.exists(lf):
            missing += 1
        else:
            if os.path.getsize(lf) > 0:
                non_empty += 1
    print(f"{os.path.basename(list_txt)}: {len(imgs)} images, {non_empty} non-empty labels, {missing} missing labels")

labels_dir = os.path.join(dataset_root, 'labels')  # this is what YOLO expects
check_label_coverage(train_list_txt, labels_dir)
check_label_coverage(val_list_txt, labels_dir)
# Out:
# Using device: mps
# train_full.txt: 2145 images, 0 non-empty labels, 2145 missing labels
# val_full.txt: 537 images, 0 non-empty labels, 537 missing labels

# %%
# 3) Train with GPU/MPS, caching and mixed precision + early stopping (lower patience)
print("\n--- 🚀 STARTING PHASE 1 TRAINING ---")
# ensure labels for phase1 are available at dataset_root/labels (you already rename earlier)
move_dir_overwrite(labels_phase1_dir, labels_dir)

model_p1 = YOLO('yolov8n.pt')
model_p1.train(
    data='phase1-data.yaml',
    epochs=50,            # reduce if you want faster cycles
    imgsz=224,            # smaller images = faster
    batch=64,
    workers=8,            # increase if you have CPU cores and fast I/O
    device=device,        # use GPU/CUDA or MPS if available
    cache=True,           # cache images for faster epochs (ram/disk)
    half=(device != 'cpu'),# use fp16 on GPU/MPS where supported
    patience=10,          # early stopping after 10 epochs without val improvement
    name='yolov8_phase1_coarse',
    exist_ok=True
)
print("--- ✅ PHASE 1 TRAINING COMPLETE ---")
# Put labels back
move_dir_overwrite(labels_dir, labels_phase1_dir)
# Out:
# --- 🚀 STARTING PHASE 1 TRAINING ---
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 809.1KB/s 7.9s.9s<0.1sss
# New https://pypi.org/project/ultralytics/8.3.247 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.217 🚀 Python-3.14.2 torch-2.9.1 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=phase1-data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=True, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8_phase1_coarse, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1661.9±364.2 MB/s, size: 44.0 KB)
# train: Scanning /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels... 2145 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2145/2145 6.7Kit/s 0.3s0.0s
# train: New cache created: /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.2GB RAM): 100% ━━━━━━━━━━━━ 2145/2145 6.8Kit/s 0.3s0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1519.9±512.9 MB/s, size: 40.2 KB)
# val: Scanning /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels... 537 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 537/537 6.8Kit/s 0.1s
# val: New cache created: /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 537/537 6.7Kit/s 0.1s
# Plotting labels to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.27G      1.692      2.847      1.308        198        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.5s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 27.0s6.4ss
#                    all        537       1602          1      0.929      0.964      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.19G       1.44       1.19       1.16        198        224: 100% ━━━━━━━━━━━━ 34/34 1.5it/s 22.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.4it/s 14.1s3.5s
#                    all        537       1602          1      0.935      0.968        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.19G      1.414      1.077      1.148        187        224: 100% ━━━━━━━━━━━━ 34/34 1.5it/s 23.3s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.6s2.6ss
#                    all        537       1602          1      0.902      0.951      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.19G      1.419       1.07      1.158        174        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 26.0s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 27.1s6.7ss
#                    all        537       1602          1      0.913      0.956      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50       2.3G      1.374      1.001      1.137        175        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 27.1s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.1it/s 34.5s9.4ss
#                    all        537       1602          1      0.946      0.973      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.24G      1.356     0.9763      1.131        214        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 26.8s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 25.9s5.8ss
#                    all        537       1602          1      0.946      0.972      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.24G      1.333      0.959      1.125        189        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 31.2s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 22.7s4.8ss
#                    all        537       1602          1      0.948      0.973       0.82
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.21G      1.319     0.9371      1.121        216        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 39.1s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 18.2s5.7ss
#                    all        537       1602          1      0.949      0.974      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.24G      1.315     0.9057      1.117        195        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 38.2s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.4it/s 13.7s4.3s
#                    all        537       1602          1      0.959      0.979      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.24G      1.281     0.8767      1.101        203        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 37.0s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 24.5s4.9ss
#                    all        537       1602          1      0.944      0.972      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.21G      1.282     0.8714      1.099        203        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 38.3s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.4it/s 13.8s4.4s
#                    all        537       1602          1      0.948      0.974      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       2.3G      1.267      0.857        1.1        208        224: 100% ━━━━━━━━━━━━ 34/34 1.0it/s 35.6s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.4s4.2s
#                    all        537       1602          1      0.948      0.974      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.21G      1.258     0.8336      1.097        171        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 39.1s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.7s4.3s
#                    all        537       1602          1      0.952      0.976      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.22G      1.254     0.8337       1.09        190        224: 100% ━━━━━━━━━━━━ 34/34 0.9it/s 37.1s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.1s.0ss
#                    all        537       1602      0.925      0.889      0.951      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.31G      1.245     0.8221      1.089        176        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 30.5s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.7s2.6ss
#                    all        537       1602          1      0.951      0.975      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.26G      1.235     0.7987      1.083        182        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 30.8s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 6.8s2.1ss
#                    all        537       1602      0.924      0.886      0.948      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.25G      1.223     0.8041       1.08        187        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 29.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.0s2.3ss
#                    all        537       1602      0.912      0.875      0.951       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.26G      1.208     0.7933      1.076        196        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.9s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.3s2.2ss
#                    all        537       1602          1      0.951      0.975       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.25G      1.214     0.7857      1.074        197        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 29.9s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 7.9s2.4ss
#                    all        537       1602          1      0.954      0.977      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.25G      1.204     0.7804      1.075        184        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.7s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 6.9s2.1ss
#                    all        537       1602          1      0.949      0.974       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.22G      1.213     0.7796      1.081        182        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 30.6s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 6.8s2.0ss
#                    all        537       1602          1      0.953      0.976      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.25G      1.201     0.7652       1.07        184        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 25.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s2.0ss
#                    all        537       1602      0.924      0.895      0.955      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.25G      1.193     0.7554      1.063        179        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 29.7s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.4s2.3ss
#                    all        537       1602      0.942      0.915      0.959      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.25G      1.178      0.742      1.064        188        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 29.8s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.1s2.2ss
#                    all        537       1602          1      0.955      0.977      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.25G      1.182     0.7405      1.062        210        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.8s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.5s2.7ss
#                    all        537       1602      0.879      0.859      0.895      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.25G      1.177     0.7324      1.063        179        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.4s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.4s2.5ss
#                    all        537       1602      0.888      0.838      0.889       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.25G      1.165     0.7376      1.063        176        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 28.3s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.3s2.0ss
#                    all        537       1602      0.923      0.886      0.956      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.25G      1.159     0.7246      1.053        198        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 26.4s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.2s2.2ss
#                    all        537       1602      0.939      0.909      0.955      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.23G      1.156     0.7214      1.057        208        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 27.5s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.7s2.2ss
#                    all        537       1602      0.938       0.91      0.955      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.23G       1.14     0.7071       1.05        185        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 27.1s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.6s2.3ss
#                    all        537       1602      0.893      0.873      0.942      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.22G      1.141     0.6954      1.046        184        224: 100% ━━━━━━━━━━━━ 34/34 1.1it/s 31.2s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.4s2.4ss
#                    all        537       1602      0.885      0.864      0.902      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.23G      1.144     0.6984       1.05        188        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 26.5s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.7s2.4ss
#                    all        537       1602      0.855       0.84      0.873       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.22G       1.14      0.694      1.045        203        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 25.2s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 7.6s2.3ss
#                    all        537       1602      0.887       0.86      0.895      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.23G      1.115     0.6758      1.036        183        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 29.2s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 7.8s2.4ss
#                    all        537       1602      0.952      0.888      0.954       0.77
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 24, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 34 epochs completed in 0.407 hours.
# Optimizer stripped from /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/weights/best.pt, 6.2MB
#
# Validating /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/weights/best.pt...
# Ultralytics 8.3.217 🚀 Python-3.14.2 torch-2.9.1 MPS (Apple M4)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 28.0s5.1ss
#                    all        537       1602          1      0.955      0.977      0.835
#                    TOP        534        675          1      0.973      0.986      0.857
#                 BOTTOM        406        407          1      0.983      0.991      0.871
#                  SHOES        520        520          1       0.91      0.955      0.776
# Speed: 0.1ms preprocess, 6.3ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse
# --- ✅ PHASE 1 TRAINING COMPLETE ---

# %%
# Add this as a new cell to move the Phase 1 model to the correct location in the repository

# !mkdir -p ../runs/detect/yolov8_phase1_coarse/weights
# !mv '/Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/weights/best.pt' ../runs/detect/yolov8_phase1_coarse/weights/

# %%
# !mv '/Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase1_coarse/weights/last.pt' ../runs/detect/yolov8_phase1_coarse/weights/

# %%
# ...existing code...

# Sanity check: ensure labels_phase2_dir exists and is populated
if not os.path.isdir(labels_phase2_dir) or len(os.listdir(labels_phase2_dir)) == 0:
    raise FileNotFoundError(f"labels_phase2_dir missing or empty: {labels_phase2_dir}")

# now DO NOT move labels_phase2_dir; switch_labels will handle it
print("\n--- 🚀 STARTING PHASE 2 TRAINING ---")
with switch_labels(labels_phase2_dir, labels_dir):
    model_p2 = YOLO('../runs/detect/yolov8_phase1_coarse/weights/best.pt')
    model_p2.train(
        data='phase2-data.yaml',
        epochs=50, imgsz=224, batch=64, workers=8,
        device=device, cache=True, half=(device!='cpu'),
        patience=10, name='yolov8_phase2_fine', exist_ok=True
    )
print("--- ✅ PHASE 2 TRAINING COMPLETE ---")

# ...existing code...
# Out:
# --- 🚀 STARTING PHASE 2 TRAINING ---
# New https://pypi.org/project/ultralytics/8.3.247 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.217 🚀 Python-3.14.2 torch-2.9.1 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=phase2-data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=True, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../runs/detect/yolov8_phase1_coarse/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8_phase2_fine, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=3 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752872  ultralytics.nn.modules.head.Detect           [8, [64, 128, 256]]
# Model summary: 129 layers, 3,012,408 parameters, 3,012,392 gradients, 8.2 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.2±0.2 ms, read: 259.1±62.0 MB/s, size: 44.0 KB)
# train: Scanning /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels... 2145 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2145/2145 8.6Kit/s 0.2s0.1s
# train: New cache created: /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.2GB RAM): 100% ━━━━━━━━━━━━ 2145/2145 6.6Kit/s 0.3s0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 243.9±91.2 MB/s, size: 39.2 KB)
# val: Scanning /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels... 537 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 537/537 6.4Kit/s 0.1s
# val: New cache created: /Users/macm4/repositories/2Phase-Object-Detection/dataset/colorful_fashion_dataset_for_object_detection/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 537/537 6.5Kit/s 0.1s
# Plotting labels to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.27G      1.195      3.374      1.089        198        224: 100% ━━━━━━━━━━━━ 34/34 1.0it/s 33.6s1.0ss
# WARNING ⚠️ NMS time limit 8.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 1/5 0.0it/s 17.3s<3:50WARNING ⚠️ NMS time limit 8.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 40% ━━━━╸─────── 2/5 0.0it/s 34.6s<1:42WARNING ⚠️ NMS time limit 8.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.1it/s 1:0719.7ss
#                    all        537       1602          1      0.564      0.782      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.34G      1.253      1.671      1.133        198        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 25.3s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 24.5s7.3ss
#                    all        537       1602      0.918      0.893      0.948      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.34G      1.216      1.118      1.108        187        224: 100% ━━━━━━━━━━━━ 34/34 1.4it/s 24.1s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 18.4s4.0ss
#                    all        537       1602      0.798      0.792      0.863      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.27G      1.209      1.057      1.101        174        224: 100% ━━━━━━━━━━━━ 34/34 1.4it/s 24.5s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.4s.0ss
#                    all        537       1602      0.775      0.757      0.807      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.29G      1.195      1.015      1.092        175        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 25.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.1s.2ss
#                    all        537       1602       0.76      0.787      0.838      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.28G       1.19     0.9859       1.09        214        224: 100% ━━━━━━━━━━━━ 34/34 1.4it/s 24.3s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.4s.1ss
#                    all        537       1602      0.783      0.798      0.839      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.28G       1.17     0.9791      1.083        189        224: 100% ━━━━━━━━━━━━ 34/34 1.2it/s 27.7s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 10.0s.2ss
#                    all        537       1602      0.824      0.799      0.861      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.28G      1.167     0.9615      1.077        216        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 25.7s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.5it/s 9.6s3.0ss
#                    all        537       1602      0.778      0.803      0.843      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.28G      1.167     0.9517      1.072        195        224: 100% ━━━━━━━━━━━━ 34/34 1.4it/s 24.2s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.4s2.4ss
#                    all        537       1602      0.818      0.766      0.838        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.28G      1.154     0.9284      1.059        203        224: 100% ━━━━━━━━━━━━ 34/34 1.4it/s 24.6s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.5s2.4ss
#                    all        537       1602      0.785      0.816      0.856      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.34G       1.15     0.9204      1.056        203        224: 100% ━━━━━━━━━━━━ 34/34 1.3it/s 26.1s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.8s2.6ss
#                    all        537       1602      0.807      0.806      0.857      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.28G      1.146     0.9084      1.059        208        224: 100% ━━━━━━━━━━━━ 34/34 1.5it/s 23.0s0.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 7.7s2.4ss
#                    all        537       1602       0.83      0.797      0.853      0.619
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 2, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 12 epochs completed in 0.142 hours.
# Optimizer stripped from /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine/weights/best.pt, 6.2MB
#
# Validating /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine/weights/best.pt...
# Ultralytics 8.3.217 🚀 Python-3.14.2 torch-2.9.1 MPS (Apple M4)
# Model summary (fused): 72 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.1it/s 37.7s9.3ss
#                    all        537       1602      0.918      0.894      0.948      0.805
#                 jacket        179        181      0.423      0.829      0.759      0.545
#                  shirt        361        366          1      0.888      0.968      0.823
#                  pants        114        114          1       0.93      0.986      0.889
#                 shorts        107        107          1      0.912      0.976      0.826
#                  skirt        186        186          1      0.919      0.995      0.893
#                  dress        128        128          1      0.898      0.995      0.879
#                   shoe        520        520          1      0.879      0.956      0.779
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 10.5ms postprocess per image
# Results saved to /Users/macm4/repositories/Machine Learning Model/modisch-model/runs/detect/yolov8_phase2_fine
# --- ✅ PHASE 2 TRAINING COMPLETE ---

# %% [markdown]
# GitHub Copilot
#
# Cause
# You’re renaming a directory onto an existing non-empty directory. On macOS, os.rename can’t overwrite a non-empty destination, and your cell calls rename twice (safe_rename + os.rename), making it more likely to fail.
#
# Quick fix in your notebook
# - Add this helper once.
# - Replace both os.rename(...) calls with move_dir_overwrite(...).
# - Remove the duplicate rename line.

# %%
# Add once in a notebook cell
import os, shutil

def move_dir_overwrite(src, dst):
    if not os.path.exists(src):
        print(f"Skip move: missing {src}")
        return
    if os.path.exists(dst):
        # avoid rmtree if they are the same inode
        try:
            if os.path.samefile(src, dst):
                return
        except FileNotFoundError:
            pass
        shutil.rmtree(dst)
    shutil.move(src, dst)

# %% [markdown]
# Use it around training

# %% [markdown]
# Cleaner alternative
# Use your existing context manager to avoid manual moves entirely:

# %% [markdown]
# Note
# - Ensure there’s no second os.rename after the move_dir_overwrite or within the context-managed block.

# %%
print("\n--- 🕵️‍♂️ RUNNING HIERARCHICAL PREDICTION ---")

# --- Load both trained models ---
model_coarse_path = os.path.join('..', 'runs', 'detect', 'yolov8_phase1_coarse', 'weights', 'best.pt')
model_fine_path = os.path.join('..', 'runs', 'detect', 'yolov8_phase2_fine', 'weights', 'best.pt')

# --- Helper function for IoU ---
def calculate_iou(box1, box2):
    x1_inter = max(box1[0], box2[0])
    y1_inter = max(box1[1], box2[1])
    x2_inter = min(box1[2], box2[2])
    y2_inter = min(box1[3], box2[3])
    inter_area = max(0, x2_inter - x1_inter) * max(0, y2_inter - y1_inter)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0

# --- Select a random image to test ---
test_image_name = random.choice(os.listdir(jpeg_dir))
test_image_path = os.path.join(jpeg_dir, test_image_name)
print(f"-> Testing on image: {test_image_name}")

img = cv2.imread(test_image_path)
results_coarse = model_coarse(img, verbose=False)[0]
results_fine = model_fine(img, verbose=False)[0]
IOU_THRESHOLD = 0.7

for fine_box in results_fine.boxes:
    fine_xyxy = fine_box.xyxy[0].cpu().numpy()
    fine_class_name = model_fine.names[int(fine_box.cls)]
    best_match_coarse_name = "Unknown"
    max_iou = 0
    
    for coarse_box in results_coarse.boxes:
        iou = calculate_iou(fine_xyxy, coarse_box.xyxy[0].cpu().numpy())
        if iou > max_iou:
            max_iou = iou
            best_match_coarse_name = model_coarse.names[int(coarse_box.cls)]
    
    label = f"{best_match_coarse_name}: {fine_class_name}" if max_iou > IOU_THRESHOLD else fine_class_name
        
    x1, y1, x2, y2 = map(int, fine_xyxy)
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# --- Display the final result ---
plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Hierarchical Prediction Result")
plt.axis('off')
plt.show()
# Out:
# --- 🕵️‍♂️ RUNNING HIERARCHICAL PREDICTION ---
# -> Testing on image: 190118.jpg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 25
#      22 print(f"-> Testing on image: {test_image_name}")
#      24 img = cv2.imread(test_image_path)
# ---> 25 results_coarse = model_coarse(img, verbose=False)[0]
#      26 results_fine = model_fine(img, verbose=False)[0]
#      27 IOU_THRESHOLD = 0.7
#
# NameError: name 'model_coarse' is not defined
